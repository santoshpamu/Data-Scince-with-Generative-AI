# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step-1: Load The data

# %%
df=pd.read_csv(r"C:\Users\home\Downloads\diamonds.csv")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ### Step-2: Exploratory data Analysis

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
#Univarient Analysis -categorica column
fig,axs=plt.subplots(1,3,figsize=(12,3), constrained_layout=True)
fig.suptitle("Univarient Analysis-Categorical column")

axs[0].set_title("cut")
sns.countplot(data=df,x='cut',ax=axs[0])

axs[1].set_title('color')
sns.countplot(data=df,x='color',ax=axs[1])

axs[2].set_title('clarity')
sns.countplot(data=df,x='clarity',ax=axs[2])
# Out:
# <Axes: title={'center': 'clarity'}, xlabel='clarity', ylabel='count'>

# %%
 #Bivarient Analysis- Cateorical  vs  Numerical

fig,axs=plt.subplots(1,3,figsize=(12,3),constrained_layout=True)
plt.suptitle('categorical   vs  numerical')

axs[0].set_title('Cut vs Price')
sns.boxplot(data=df,x='cut',y='price',ax=axs[0],orient='h')

axs[1].set_title('color vs Price')
sns.boxplot(data=df,x='color',y='price',ax=axs[1],orient='h')

axs[2].set_title('clarity  vs price')
sns.boxplot(data=df,x='clarity',y='price',axa=axs[2],orient='h')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 13
#      10 sns.boxplot(data=df,x='color',y='price',ax=axs[1],orient='h')
#      12 axs[2].set_title('clarity  vs price')
# ---> 13 sns.boxplot(data=df,x='clarity',y='price',axa=axs[2],orient='h')
#      14 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1634, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
#    1632 linecolor = p._complement_color(linecolor, color, p._hue_map)
# -> 1634 p.plot_boxes(
# ...

# %% [markdown]
# ### step-3: Segregating Input and Target variable

# %%
X=df.drop(columns=['price'])
y=df['price']

#X = df.iloc[:, :-1]  # All rows, all columns except the last one (Features)
# = df.iloc[:, -1]   # All rows, last column (Target)

# %%
X
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 9 columns]

# %%
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# ### Step-4:Split the data into train and test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)
print('X_train.shape',X_train.shape)
print('X_test.shape',X_test.shape)
print('y_train.shape',y_train.shape)
print('y_test.shape',y_test.shape)
# Out:
# X_train.shape (40455, 9)
# X_test.shape (13485, 9)
# y_train.shape (40455,)
# y_test.shape (13485,)

# %% [markdown]
# ### Step-5:Apply  Data Preparation on Training data

# %%
X_train.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# ##### Step 5.1: Separating numerical and categorical features

# %%
X_train_num=X_train.select_dtypes(include=['int64','float64'])
X_train_cat=X_train.select_dtypes(include=['object'])

# %%
X_train_num.head()
# Out:
#        carat  depth  table     x     y     z
# 441     0.89   60.2   59.0  6.26  6.23  3.76
# 50332   0.70   64.0   53.0  5.57  5.61  3.58
# 35652   0.31   62.7   57.0  4.33  4.31  2.71
# 9439    0.90   62.3   59.0  6.12  6.17  3.83
# 15824   1.01   60.6   62.0  6.52  6.49  3.94

# %%
X_train_cat.head()
# Out:
#              cut color clarity
# 441      Premium     H     SI2
# 50332  Very Good     D     SI1
# 35652      Ideal     G    VVS2
# 9439   Very Good     H     VS1
# 15824       Good     F     VS2

# %% [markdown]
# ##### 5.2 Numerical feature transformation ("Standardization")

# %% [markdown]
# ##### --> eventhough data is  in numerical format we perform standardization because to rescale every thing into same range

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_num_transformed=pd.DataFrame(sc.fit_transform(X_train_num),
                                     columns=sc.get_feature_names_out(),#column names are converted to numpyarray  if we use this columns names will be remain constant
                                     index=X_train_num.index)
X_train_num_transformed.head()
# Out:
#           carat     depth     table         x         y         z
# 441    0.194920 -1.085697  0.694368  0.472201  0.430971  0.312528
# 50332 -0.205679  1.567623 -1.997562 -0.142482 -0.107276  0.058918
# 35652 -1.027961  0.659908 -0.202942 -1.247129 -1.235860 -1.166861
# 9439   0.216004  0.380611  0.694368  0.347483  0.378883  0.411154
# 15824  0.447930 -0.806400  2.040332  0.703821  0.656688  0.566137

# %% [markdown]
# ##### Lets analyse the Properties of each column using standardscaler

# %%
print('number of numerical features:',    sc.n_features_in_)
print('ouput feature names:',             sc.get_feature_names_out())
print('mean of eaach column:',            sc.mean_)
print('std of each column:',              np.sqrt(sc.var_))
# Out:
# number of numerical features: 6
# ouput feature names: ['carat' 'depth' 'table' 'x' 'y' 'z']
# mean of eaach column: [ 0.79755135 61.75490051 57.45233469  5.72994018  5.73356989  3.53818267]
# std of each column: [0.47428986 1.43216771 2.22888453 1.1225301  1.15188634 0.7097527 ]

# %%
X_train_num_transformed.round(2).head()
# Out:
#        carat  depth  table     x     y     z
# 441     0.19  -1.09   0.69  0.47  0.43  0.31
# 50332  -0.21   1.57  -2.00 -0.14 -0.11  0.06
# 35652  -1.03   0.66  -0.20 -1.25 -1.24 -1.17
# 9439    0.22   0.38   0.69  0.35  0.38  0.41
# 15824   0.45  -0.81   2.04  0.70  0.66  0.57

# %%
cut_categories = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_categories = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
clarity_categories = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

# %% [markdown]
# ##### 5.3 numerical feature transformation using Ordinal encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal=OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories],
                      handle_unknown='use_encoded_value',
                      unknown_value=-1,
                      encoded_missing_value=-5)

# %%
X_train_cat_transformed=pd.DataFrame(ordinal.fit_transform(X_train_cat),
                                     columns=ordinal.get_feature_names_out(),
                                    index=X_train_cat.index)
X_train_cat_transformed.head()
# Out:
#        cut  color  clarity
# 441    3.0    2.0      1.0
# 50332  2.0    6.0      2.0
# 35652  4.0    3.0      5.0
# 9439   2.0    2.0      4.0
# 15824  1.0    4.0      3.0

# %%
# Let's now analyse the properties of 'ordinal_encoder'

print("Applied encoding on:", ordinal.feature_names_in_)
print("Unique Categories:", ordinal.categories_)
print("Feature Names after encoding:", ordinal.get_feature_names_out())
# Out:
# Applied encoding on: ['cut' 'color' 'clarity']
# Unique Categories: [array(['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'], dtype=object), array(['J', 'I', 'H', 'G', 'F', 'E', 'D'], dtype=object), array(['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'],
#       dtype=object)]
# Feature Names after encoding: ['cut' 'color' 'clarity']

# %% [markdown]
# ### step-6: Concatenate X_train_num_transform and X_train_cat_transform

# %%
X_train_transformed=pd.concat([X_train_num_transformed,X_train_cat_transformed],axis=1)
X_train_transformed.head()
# Out:
#           carat     depth     table         x         y         z  cut  color  \
# 441    0.194920 -1.085697  0.694368  0.472201  0.430971  0.312528  3.0    2.0
# 50332 -0.205679  1.567623 -1.997562 -0.142482 -0.107276  0.058918  2.0    6.0
# 35652 -1.027961  0.659908 -0.202942 -1.247129 -1.235860 -1.166861  4.0    3.0
# 9439   0.216004  0.380611  0.694368  0.347483  0.378883  0.411154  2.0    2.0
# 15824  0.447930 -0.806400  2.040332  0.703821  0.656688  0.566137  1.0    4.0
#
#        clarity
# 441        1.0
# 50332      2.0
# 35652      5.0
# 9439       4.0
# 15824      3.0

# %% [markdown]
# #### Step-7: Applying Data Preparation on Test Data

# %%
X_test_num=X_test.select_dtypes(include=['int64','float64'])
X_test_cat=X_test.select_dtypes(include=['object'])

# %%
X_test_num_transformed=pd.DataFrame(sc.transform(X_test_num),
                                    columns=sc.get_feature_names_out(),
                                    index=X_test_num.index)
X_test_num_transformed.head()
# Out:
#           carat     depth     table         x         y         z
# 10176  0.637687  0.171139 -1.100252  0.783997  0.795591  0.805657
# 16083  1.038286  0.590084 -0.651597  1.095792  1.038670  1.143803
# 13420  0.848529 -0.457279  0.245713  1.024525  0.925812  0.904283
# 20407  1.481053 -0.596928 -0.651597  1.514489  1.411971  1.355144
# 8909   0.216004 -0.038334 -0.202942  0.392025  0.413609  0.397064

# %%
X_test_cat_transformed=pd.DataFrame(ordinal.transform(X_test_cat),
                                    columns=ordinal.get_feature_names_out(),
                                    index=X_test_cat.index)
X_test_cat_transformed.head()
# Out:
#        cut  color  clarity
# 10176  4.0    2.0      1.0
# 16083  4.0    2.0      2.0
# 13420  3.0    1.0      2.0
# 20407  4.0    4.0      2.0
# 8909   2.0    4.0      3.0

# %% [markdown]
# ##### Step7.1 :Concatenate X_test_num_transformed and X_test_cat_transformed

# %%
X_test_transformed=pd.concat([X_test_num_transformed,X_test_cat_transformed],axis=1)
X_test_transformed.head().round(2)
# Out:
#        carat  depth  table     x     y     z  cut  color  clarity
# 10176   0.64   0.17  -1.10  0.78  0.80  0.81  4.0    2.0      1.0
# 16083   1.04   0.59  -0.65  1.10  1.04  1.14  4.0    2.0      2.0
# 13420   0.85  -0.46   0.25  1.02  0.93  0.90  3.0    1.0      2.0
# 20407   1.48  -0.60  -0.65  1.51  1.41  1.36  4.0    4.0      2.0
# 8909    0.22  -0.04  -0.20  0.39  0.41  0.40  2.0    4.0      3.0

# %% [markdown]
# ### Step-8:Training a model

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train_transformed,y_train)
# Out:
# LinearRegression()

# %%
y_test_pred=regression.predict(X_test_transformed)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
print("model's Error:",metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# model's Error: 806.1632101815314

# %%
#model's Error: 806.1632101815314
#Average Prediction Error: On average, your model's predictions are off by 806.16 units from the actual diamond prices. If your prices are in USD, this means each predicted diamond price is, on average, $806.16 higher or lower than the true price.

# %%
comparing_df=pd.DataFrame({'Actual':y_test,'Linear Regression Prediction':y_test_pred})
comparing_df
# Out:
#        Actual  Linear Regression Prediction
# 10176    4733                   5131.107679
# 16083    6424                   7294.764679
# 13420    5510                   6025.770217
# 20407    8770                   9927.067650
# 8909     4493                   4732.652453
# ...       ...                           ...
# 52283    2494                   3348.611770
# 10789    4861                   4480.310760
# 1190     2932                   3870.804522
# 3583     3422                   4198.061830
# 40845    1173                   1404.257826
#
# [13485 rows x 2 columns]

# %%
fig,ax=plt.subplots(figsize=(12,3))
sns.histplot(comparision['Actual'],color='blue',alpha=0.5,label='Actual')
sns.histplot(comparision['Linear Regression Prediction'],color='red',alpha=0.5,label="prediction")
plt.legend()

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor=KNeighborsRegressor()
regressor.fit(X_train_transformed,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_test_pred=regressor.predict(X_test_transformed)

# %%
print("Model's error:",metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# Model's error: 381.08851316277344

# %%
comparing_df['KNN regressor Prediction']=y_test_pred
comparing_df
# Out:
#        Actual  Linear Regression Prediction  KNN regressor Prediction
# 10176    4733                   5131.107679                    4664.4
# 16083    6424                   7294.764679                    6278.2
# 13420    5510                   6025.770217                    5180.8
# 20407    8770                   9927.067650                   12080.0
# 8909     4493                   4732.652453                    6015.2
# ...       ...                           ...                       ...
# 52283    2494                   3348.611770                    2445.2
# 10789    4861                   4480.310760                    4301.8
# 1190     2932                   3870.804522                    3569.6
# 3583     3422                   4198.061830                    3228.2
# 40845    1173                   1404.257826                    1533.4
#
# [13485 rows x 3 columns]

# %%
fig,ax=plt.subplots(figsize=(12,3))
sns.histplot(comparision['Actual'],color='blue',alpha=0.5,label='Actual')
sns.histplot(comparision['KNN regressor Prediction'],color='red',alpha=0.5,label="prediction")
plt.legend()

# %%
from sklearn.tree import DecisionTreeRegressor
tree=DecisionTreeRegressor()
tree.fit(X_train_transformed,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_test_pred=tree.predict(X_test_transformed)

# %%
print("Model's Error:",metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# Model's Error: 351.0040044493882

# %%
comparing_df['DT regressor Prediction']=y_test_pred
comparing_df
# Out:
#        Actual  Linear Regression Prediction  KNN regressor Prediction  \
# 10176    4733                   5131.107679                    4664.4
# 16083    6424                   7294.764679                    6278.2
# 13420    5510                   6025.770217                    5180.8
# 20407    8770                   9927.067650                   12080.0
# 8909     4493                   4732.652453                    6015.2
# ...       ...                           ...                       ...
# 52283    2494                   3348.611770                    2445.2
# 10789    4861                   4480.310760                    4301.8
# 1190     2932                   3870.804522                    3569.6
# 3583     3422                   4198.061830                    3228.2
# 40845    1173                   1404.257826                    1533.4
#
#        DT regressor Prediction
# 10176                   4662.0
# 16083                   7109.0
# ...

# %%
fig,ax=plt.subplots(figsize=(12,3))
sns.histplot(comparision['Actual'],color='blue',alpha=0.5,label='Actual')
sns.histplot(comparision['DT regressor Prediction'],color='red',alpha=0.5,label="prediction")
plt.legend()

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor=RandomForestRegressor()
rf_regressor.fit(X_train_transformed,y_train)
# Out:
# RandomForestRegressor()

# %%
y_test_pred=rf_regressor.predict(X_test_transformed)

# %%
print("model's Error:",metrics.mean_absolute_error(y_test,y_test_pred))
# Out:
# model's Error: 268.5230745263697

# %%
comparing_df['RF regression']=y_test_pred
comparing_df
# Out:
#        Actual  Linear Regression Prediction  KNN regressor Prediction  \
# 10176    4733                   5131.107679                    4664.4
# 16083    6424                   7294.764679                    6278.2
# 13420    5510                   6025.770217                    5180.8
# 20407    8770                   9927.067650                   12080.0
# 8909     4493                   4732.652453                    6015.2
# ...       ...                           ...                       ...
# 52283    2494                   3348.611770                    2445.2
# 10789    4861                   4480.310760                    4301.8
# 1190     2932                   3870.804522                    3569.6
# 3583     3422                   4198.061830                    3228.2
# 40845    1173                   1404.257826                    1533.4
#
#        DT regressor Prediction  RF regression
# 10176                   4662.0       4724.490
# ...

# %%
fig,ax=plt.subplots(figsize=(12,3))
sns.histplot(comparing_df['Actual'],color='blue',alpha=0.5,label='Actual')
sns.histplot(comparing_df['RF regression'],color='red',alpha=0.5,label="prediction")
plt.legend()

# %%
df_melted=pd.melt(comparing_df,var_name='Model',value_name='Prediction')
df_melted
# Out:
#                Model  Prediction
# 0             Actual    4733.000
# 1             Actual    6424.000
# 2             Actual    5510.000
# 3             Actual    8770.000
# 4             Actual    4493.000
# ...              ...         ...
# 67420  RF regression    2434.720
# 67421  RF regression    4424.340
# 67422  RF regression    3041.555
# 67423  RF regression    2910.630
# 67424  RF regression    1273.450
#
# [67425 rows x 2 columns]

# %%
models = ['Linear Regression', 'KNN Regression', 'Decision Tree', 'Random Forest']
errors = [806.1632101815314, 381.08851316277344, 351.0040044493882, 268.5230745263697]

# Create a bar plot to compare the models' errors
plt.figure(figsize=(8, 4))
plt.bar(models, errors, color=['red', 'blue', 'green', 'purple'])
plt.title('Comparison of Model Errors')
plt.xlabel('Models')
plt.ylabel('Error')
plt.ylim(0, 850)

# Display the plot
plt.show()

# %% [markdown]
# ## Conclusion
# Out of all models and after comparing them Random forest has least error rate,so Random Forest is best
